# %%
import pandas as pd
df=pd.read_json('nobel_winners.json')
df
# Out:
#                      born_in                category    country  \
# 0                             Physiology or Medicine  Argentina
# 1     Bosnia and Herzegovina              Literature
# 2     Bosnia and Herzegovina               Chemistry
# 3                                              Peace    Belgium
# 4                                              Peace    Belgium
# ...                      ...                     ...        ...
# 1047                                         Physics  Australia
# 1048                                           Peace  Argentina
# 1049                          Physiology or Medicine  Argentina
# 1050                                       Chemistry  Argentina
# 1051                                           Peace  Argentina
#
#           date_of_birth   date_of_death gender  \
# 0        8 October 1927   24 March 2002   male
# 1        9 October 1892   13 March 1975   male
# 2         July 23, 1906      1998-01-07   male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   born_in         1052 non-null   object
#  1   category        1052 non-null   object
#  2   country         1052 non-null   object
#  3   date_of_birth   1044 non-null   object
#  4   date_of_death   1044 non-null   object
#  5   gender          1040 non-null   object
#  6   link            1052 non-null   object
#  7   name            1052 non-null   object
#  8   place_of_birth  1044 non-null   object
#  9   place_of_death  1044 non-null   object
#  10  text            1052 non-null   object
#  11  year            1052 non-null   int64
# dtypes: int64(1), object(11)
# memory usage: 98.8+ KB

# %%
df.describe()
# Out:
#               year
# count  1052.000000
# mean   1968.729087
# std      33.155829
# min    1809.000000
# 25%    1947.000000
# 50%    1975.000000
# 75%    1996.000000
# max    2014.000000

# %%
df.describe(include='object')
# Out:
#        born_in                category        country    date_of_birth  \
# count     1052                    1052           1052             1044
# unique      40                       7             59              853
# top             Physiology or Medicine  United States  7 November 1867
# freq       910                     250            350                4
#
#        date_of_death gender                                         link  \
# count           1044   1040                                         1052
# unique           563      2                                          893
# top                    male  http://en.wikipedia.org/wiki/Michael_Levitt
# freq             362    982                                            4
#
#                   name place_of_birth place_of_death  \
# count             1052           1044           1044
# unique             998            735            410
# top     César Milstein
# freq                 2             29            409
#
# ...

# %%
df.describe(include='all')
# Out:
#        born_in                category        country    date_of_birth  \
# count     1052                    1052           1052             1044
# unique      40                       7             59              853
# top             Physiology or Medicine  United States  7 November 1867
# freq       910                     250            350                4
# mean       NaN                     NaN            NaN              NaN
# std        NaN                     NaN            NaN              NaN
# min        NaN                     NaN            NaN              NaN
# 25%        NaN                     NaN            NaN              NaN
# 50%        NaN                     NaN            NaN              NaN
# 75%        NaN                     NaN            NaN              NaN
# max        NaN                     NaN            NaN              NaN
#
#        date_of_death gender                                         link  \
# ...

# %%
df = df.set_index('name')
# df = df.reset_index()
df.head(2)
# Out:
#                                born_in                category    country  \
# name
# César Milstein                          Physiology or Medicine  Argentina
# Ivo Andric *    Bosnia and Herzegovina              Literature
#
#                  date_of_birth  date_of_death gender  \
# name
# César Milstein  8 October 1927  24 March 2002   male
# Ivo Andric *    9 October 1892  13 March 1975   male
#
#                                                             link  \
# name
# César Milstein  http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# Ivo Andric *             http://en.wikipedia.org/wiki/Ivo_Andric
#
#                                                    place_of_birth  \
# name
# César Milstein                          Bahía Blanca ,  Argentina
# Ivo Andric *    Dolac (village near Travnik), Austria-Hungary ...
#
#                                                    place_of_death  \
# name
# César Milstein                                Cambridge , England
# ...

# %%
df.reset_index(inplace=True)
df.head(2)
# Out:
#              name                 born_in                category    country  \
# 0  César Milstein                          Physiology or Medicine  Argentina
# 1    Ivo Andric *  Bosnia and Herzegovina              Literature
#
#     date_of_birth  date_of_death gender  \
# 0  8 October 1927  24 March 2002   male
# 1  9 October 1892  13 March 1975   male
#
#                                                link  \
# 0  http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# 1           http://en.wikipedia.org/wiki/Ivo_Andric
#
#                                       place_of_birth  \
# 0                          Bahía Blanca ,  Argentina
# 1  Dolac (village near Travnik), Austria-Hungary ...
#
#                                       place_of_death  \
# 0                                Cambridge , England
# 1  Belgrade, SR Serbia, SFR Yugoslavia (present-d...
#
#                                                 text  year
# 0      César Milstein , Physiology or Medicine, 1984  1984
# ...

# %%
df.columns
# Out:
# Index(['name', 'born_in', 'category', 'country', 'date_of_birth',
#        'date_of_death', 'gender', 'link', 'place_of_birth', 'place_of_death',
#        'text', 'year'],
#       dtype='object')

# %%
df.name.describe()
# Out:
# count               1052
# unique               998
# top       César Milstein
# freq                   2
# Name: name, dtype: object

# %%
type(df.name)
# Out:
# pandas.core.series.Series

# %%
df.count()
# Out:
# name              1052
# born_in           1052
# category          1052
# country           1052
# date_of_birth     1044
# date_of_death     1044
# gender            1040
# link              1052
# place_of_birth    1044
# place_of_death    1044
# text              1052
# year              1052
# dtype: int64

# %%
# mask = df.year > 2013
# mask = (df.year > 2013) & (df.category == 'Physics') # 遮罩
mask = (df.year >= 2000) & (df.year <= 2010) &  (df.category == 'Economics')
df[mask]
# Out:
#                           name         born_in   category        country  \
# 32   Christopher A. Pissarides                  Economics         Cyprus
# 93             Daniel Kahneman                  Economics         Israel
# 96               Robert Aumann                  Economics         Israel
# 438         Daniel L. McFadden                  Economics  United States
# 439           James J. Heckman                  Economics  United States
# 445          A. Michael Spence                  Economics  United States
# 446          George A. Akerlof                  Economics  United States
# 447         Joseph E. Stiglitz                  Economics  United States
# 456            Vernon L. Smith                  Economics  United States
# 457            Daniel Kahneman                  Economics  United States
# 461            Robert F. Engle                  Economics  United States
# 469         Edward C. Prescott                  Economics  United States
# ...

# %%
df.born_in.describe()
# Out:
# count     1052
# unique      40
# top
# freq       910
# Name: born_in, dtype: object

# %%
df[df.born_in == '']
# Out:
#                                  name born_in                category  \
# 0                      César Milstein          Physiology or Medicine
# 3     Institut de Droit International                           Peace
# 4                   Auguste Beernaert                           Peace
# 5                 Maurice Maeterlinck                      Literature
# 6                   Henri La Fontaine                           Peace
# ...                               ...     ...                     ...
# 1047                 Brian P. Schmidt                         Physics
# 1048            Carlos Saavedra Lamas                           Peace
# 1049                 Bernardo Houssay          Physiology or Medicine
# 1050             Luis Federico Leloir                       Chemistry
# 1051            Adolfo Pérez Esquivel                           Peace
#
#         country      date_of_birth   date_of_death gender  \
# 0     Argentina     8 October 1927   24 March 2002   male
# ...

# %%
import numpy as np #abc          replace('ab','AB')
df.born_in.replace('',np.nan,inplace=True) # df.欄位.replace('舊值','新值')  欄位必須與舊值完全符合才會執行
df.born_in.describe()
# Out:
# count         142
# unique         39
# top       Germany
# freq           21
# Name: born_in, dtype: object

# %%
mask4=df.name.str.contains('\*')
df[mask4].name
# Out:
# 1                   Ivo Andric *
# 2              Vladimir Prelog *
# 14               Simon Kuznets *
# 15              Menachem Begin *
# 16                Shimon Peres *
#                   ...
# 1034            Martin Karplus *
# 1035    William Lawrence Bragg *
# 1039    Aleksandr M. Prokhorov *
# 1041     John Warcup Cornforth *
# 1046    Elizabeth H. Blackburn *
# Name: name, Length: 142, dtype: object

# %%
# df.born_in = df.born_in.replace('',np.nan) # df.欄位.replace('舊值','新值')  欄位必須與舊值完全符合才會執行
df.name = df.name.str.replace('*','',regex=True) # df.欄位.str.replace('舊值','新值')  針對欄位中的舊值替換維新值
df.name = df.name.str.strip()
df.name
# Out:
# 0                        César Milstein
# 1                            Ivo Andric
# 2                       Vladimir Prelog
# 3       Institut de Droit International
# 4                     Auguste Beernaert
#                      ...
# 1047                   Brian P. Schmidt
# 1048              Carlos Saavedra Lamas
# 1049                   Bernardo Houssay
# 1050               Luis Federico Leloir
# 1051              Adolfo Pérez Esquivel
# Name: name, Length: 1052, dtype: object

# %%
df_bornin=df[~df.born_in.isna()].count()
df_bornin # 將born_in欄位獨立保留
# Out:
# name              142
# born_in           142
# category          142
# country           142
# date_of_birth     142
# date_of_death     142
# gender            140
# link              142
# place_of_birth    142
# place_of_death    142
# text              142
# year              142
# dtype: int64

# %%
# df=df.drop('born_in',axis=1) # 刪除born_in欄位
df.columns
# Out:
# Index(['name', 'category', 'country', 'date_of_birth', 'date_of_death',
#        'gender', 'link', 'place_of_birth', 'place_of_death', 'text', 'year'],
#       dtype='object')

# %%
# df[df.name=='César Milstein']
df[df.duplicated('name')].name
mask_dupes = df.name.isin(df[df.duplicated('name')].name)
df[mask_dupes]
# Out:
#                         name                category    country  \
# 0             César Milstein  Physiology or Medicine  Argentina
# 2            Vladimir Prelog               Chemistry
# 11         Christian de Duve  Physiology or Medicine    Belgium
# 12            Ilya Prigogine               Chemistry    Belgium
# 14             Simon Kuznets               Economics
# ...                      ...                     ...        ...
# 1039  Aleksandr M. Prokhorov                 Physics
# 1040           Patrick White              Literature  Australia
# 1042           John Harsanyi               Economics  Australia
# 1047        Brian P. Schmidt                 Physics  Australia
# 1050    Luis Federico Leloir               Chemistry  Argentina
#
#           date_of_birth      date_of_death gender  \
# 0        8 October 1927      24 March 2002   male
# 2         July 23, 1906         1998-01-07   male
# 11       2 October 1917         4 May 2013   male
# ...

# %%
# df[mask_dupes].sort_values(['name'],ascending=[1])
df[mask_dupes].sort_values(['name','country'],ascending=[1,1])
# Out:
#                           name   category         country     date_of_birth  \
# 106                 Aaron Klug  Chemistry                    11 August 1926
# 121                 Aaron Klug  Chemistry    South Africa    11 August 1926
# 131                 Aaron Klug  Chemistry  United Kingdom    11 August 1926
# 742            Alan MacDiarmid  Chemistry                     14 April 1927
# 440            Alan MacDiarmid  Chemistry   United States     14 April 1927
# ...                        ...        ...             ...               ...
# 417            William Vickrey  Economics   United States      21 June 1914
# 773             Yoichiro Nambu    Physics           Japan  January 18, 1921
# 489             Yoichiro Nambu    Physics   United States  January 18, 1921
# 1010  Zhores Ivanovich Alferov    Physics                        1930-03-15
# 692   Zhores Ivanovich Alferov    Physics          Russia        1930-03-15
#
#         date_of_death gender  \
# ...

# %%
df[mask_dupes].groupby('name').count()
# Out:
#                           category  country  date_of_birth  date_of_death  \
# name
# Aaron Klug                       3        3              3              3
# Alan MacDiarmid                  2        2              2              2
# Albert Einstein                  2        2              2              2
# Albert Schweitzer                2        2              2              2
# Aleksandr M. Prokhorov           2        2              2              2
# ...                            ...      ...            ...            ...
# William Giauque                  2        2              2              2
# William Lawrence Bragg           2        2              2              2
# William Vickrey                  2        2              2              2
# Yoichiro Nambu                   2        2              2              2
# Zhores Ivanovich Alferov         2        2              2              2
#
# ...

# %%
df[df.duplicated(['name','year'])].count()
df = df.reindex(np.random.permutation(df.index))
df[mask_dupes].sort_values(['name'],ascending=[1])
# Out:
# C:\Users\Lyumin\AppData\Local\Temp/ipykernel_8560/515986406.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[mask_dupes].sort_values(['name'],ascending=[1])
#                          name   category         country     date_of_birth  \
# 106                Aaron Klug  Chemistry                    11 August 1926
# 440           Alan MacDiarmid  Chemistry   United States     14 April 1927
# 615           Albert Einstein    Physics     Switzerland        1879-03-14
# 38          Albert Schweitzer      Peace          France   14 January 1875
# 680    Aleksandr M. Prokhorov    Physics          Russia      11 July 1916
# ..                        ...        ...             ...               ...
# 270           William Giauque  Chemistry   United States      May 12, 1895
# 525    William Lawrence Bragg    Physics  United Kingdom     31 March 1890
# 417           William Vickrey  Economics   United States      21 June 1914
# ...

# %%
df = df.drop_duplicates(['name','year'])  # drop_duplicates會將後面的資料移除
df = df.sort_index()
df.count()
# df[mask_dupes].sort_values(['name'],ascending=[1])
# Out:
# C:\Users\Lyumin\AppData\Local\Temp/ipykernel_8560/372103567.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[mask_dupes].sort_values(['name'],ascending=[1])
#                          name   category         country     date_of_birth  \
# 106                Aaron Klug  Chemistry                    11 August 1926
# 440           Alan MacDiarmid  Chemistry   United States     14 April 1927
# 615           Albert Einstein    Physics     Switzerland        1879-03-14
# 38          Albert Schweitzer      Peace          France   14 January 1875
# 680    Aleksandr M. Prokhorov    Physics          Russia      11 July 1916
# ..                        ...        ...             ...               ...
# 270           William Giauque  Chemistry   United States      May 12, 1895
# 525    William Lawrence Bragg    Physics  United Kingdom     31 March 1890
# 417           William Vickrey  Economics   United States      21 June 1914
# ...

# %%
df[df.year==1809]
# Out:
# Empty DataFrame
# Columns: [name, category, country, date_of_birth, date_of_death, gender, link, place_of_birth, place_of_death, text, year]
# Index: []

# %%
df.loc[958,'year'] = 1939
df.loc[959,'year'] = 1945
df.loc[960,'year'] = 1967
df.describe()
# Out:
#               year
# count   904.000000
# mean   1968.015487
# std      32.246692
# min    1901.000000
# 25%    1946.000000
# 50%    1974.000000
# 75%    1995.000000
# max    2014.000000

# %%
df[df.gender.isna()]
# Out:
#                                                    name  \
# 3                       Institut de Droit International
# 156                             Friends Service Council
# 267   American Friends Service Committee  (The Quakers)
# 574                               Amnesty International
# 632                            Médecins Sans Frontières
# 650                                       Ragnar Granit
# 960                                       Ragnar Granit
# 1000   Pugwash Conferences on Science and World Affairs
# 1033                 International Atomic Energy Agency
#
#                     category         country     date_of_birth  \
# 3                      Peace         Belgium              None
# 156                    Peace  United Kingdom              None
# 267                    Peace   United States              None
# 574                    Peace  United Kingdom              None
# 632                    Peace     Switzerland              None
# ...

# %%
df.loc[650,'gender']='male'
df.loc[989,'gender']='male' # 因亂數移除資料後與老師不同 index為320且性別有資料
# Out:
#                     name                category        country  \
# 47        Alfred Kastler                 Physics         France
# 89    Shmuel Yosef Agnon              Literature         Israel
# 319  Francis Peyton Rous  Physiology or Medicine  United States
# 320   Charles B. Huggins  Physiology or Medicine  United States
# 321   Robert S. Mulliken               Chemistry  United States
# 649          Nelly Sachs              Literature         Sweden
#
#           date_of_birth      date_of_death  gender  \
# 47           3 May 1902     7 January 1984    male
# 89        July 17, 1888  February 17, 1970    male
# 319     October 5, 1879  February 16, 1970    male
# 320  September 22, 1901   January 12, 1997    male
# 321        June 7, 1896   October 31, 1986    male
# 649    10 December 1891        12 May 1970  female
#
#                                                  link  \
# 47        http://en.wikipedia.org/wiki/Alfred_Kastler
# ...

# %%
df.drop(960,axis=0,inplace=True)

# %%
df[['name','date_of_birth']]
# Out:
#                                  name      date_of_birth
# 0                      César Milstein     8 October 1927
# 1                          Ivo Andric     9 October 1892
# 2                     Vladimir Prelog      July 23, 1906
# 3     Institut de Droit International               None
# 4                   Auguste Beernaert       26 July 1829
# ...                               ...                ...
# 1045                   Barry Marshall  30 September 1951
# 1046           Elizabeth H. Blackburn         1948-11-26
# 1048            Carlos Saavedra Lamas   November 1, 1878
# 1049                 Bernardo Houssay         1887-04-10
# 1051            Adolfo Pérez Esquivel  November 26, 1931
#
# [903 rows x 2 columns]

# %%
df.date_of_birth=pd.to_datetime(df.date_of_birth,errors='raise')
df.date_of_birth
# Out:
# 0      1927-10-08
# 1      1892-10-09
# 2      1906-07-23
# 3             NaT
# 4      1829-07-26
#           ...
# 1045   1951-09-30
# 1046   1948-11-26
# 1048   1878-11-01
# 1049   1887-04-10
# 1051   1931-11-26
# Name: date_of_birth, Length: 903, dtype: datetime64[ns]

# %%
# df[df.date_of_death=='1968-23-07']
# df.loc[150,'date_of_death'] = '1968-07-23'
# df[df.date_of_death=='May 30, 2011 (aged 89)']
# df.loc[349,'date_of_death'] = '2011-05-30'
# df[df.date_of_death=='living']
# df.loc[581,'date_of_death'] = np.nan
# df.loc[809,'date_of_death'] = np.nan
# df.loc[833,'date_of_death'] = np.nan
#df[df.date_of_death=='Diederik Korteweg']
# df.loc[746,'date_of_death'] = '1923-03-08'
df.date_of_death = pd.to_datetime(df.date_of_death,errors='coerce')
df.date_of_death
# pd.to_datetime(df.date_of_death,errors='raise')
# Out:
# 0      2002-03-24
# 1      1975-03-13
# 2      1998-01-07
# 3             NaT
# 4      1912-10-06
#           ...
# 1045          NaT
# 1046          NaT
# 1048   1959-05-05
# 1049   1971-09-21
# 1051          NaT
# Name: date_of_death, Length: 903, dtype: datetime64[ns]

# %%
df['award_age']=df.year-pd.DatetimeIndex(df.date_of_birth).year # 建立新欄位 獲獎歲數=獲獎年-生日
df
# Out:
#                                  name                category    country  \
# 0                      César Milstein  Physiology or Medicine  Argentina
# 1                          Ivo Andric              Literature
# 2                     Vladimir Prelog               Chemistry
# 3     Institut de Droit International                   Peace    Belgium
# 4                   Auguste Beernaert                   Peace    Belgium
# ...                               ...                     ...        ...
# 1045                   Barry Marshall  Physiology or Medicine  Australia
# 1046           Elizabeth H. Blackburn  Physiology or Medicine
# 1048            Carlos Saavedra Lamas                   Peace  Argentina
# 1049                 Bernardo Houssay  Physiology or Medicine  Argentina
# 1051            Adolfo Pérez Esquivel                   Peace  Argentina
#
#      date_of_birth date_of_death  gender  \
# 0       1927-10-08    2002-03-24    male
# ...

# %%
df[df.award_age<=30]
# Out:
#                        name                category         country  \
# 525  William Lawrence Bragg                 Physics  United Kingdom
# 626    Georges J. F. Köhler  Physiology or Medicine     Switzerland
# 725        Malala Yousafzai                   Peace        Pakistan
#
#     date_of_birth date_of_death  gender  \
# 525    1890-03-31    1971-07-01    male
# 626    1946-04-17    1995-03-01    male
# 725    1997-07-12           NaT  female
#
#                                                   link  \
# 525  http://en.wikipedia.org/wiki/William_Lawrence_...
# 626  http://en.wikipedia.org/wiki/Georges_J._F._K%C...
# 725      http://en.wikipedia.org/wiki/Malala_Yousafzai
#
#                        place_of_birth                    place_of_death  \
# 525  North Adelaide , South Australia  Waldringfield , Suffolk, England
# 626                            Munich              Freiburg im Breisgau
# 725                 Mingora, Pakistan
#
# ...
